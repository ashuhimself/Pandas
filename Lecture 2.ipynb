# %%
# This sheet is designed to learn Pandas from scratch. I have used stack over flow data you can find data here 

https://insights.stackoverflow.com/survey

# %%
import pandas as pd

# %%
df= pd.read_csv('Data2020/survey_results_public.csv')
schema_df = pd.read_csv('Data2020/survey_results_schema.csv')
df1 = pd.read_csv('Data2021/survey_results_public.csv')#to load data to panadas
schema_df1 = pd.read_csv('Data2021/survey_results_schema.csv')

# %%
pd.set_option('Display.max_columns',85)
pd.set_option('Display.max_rows',85)

# %%
df.head()

# %%
#to create a data frame in Pandas

#Dataframe_name = {keys:value}

# but we have to put multiple value in one key that's why we use list

People = {'Name' : ['Ashutosh','Akash','Anuj','Chand','Amit','Narendra','Salaman'],
          'Email' : ['abc@email.com','cv@gmail.com','Abc@gmail.com','hgj@mail.com','xyz@mail.com','loloo@mail.com','fgv@mail.com'], 
          'Number':['887773','3343443','34334343','34334343','3434343532','867556545',
'35467887655']}

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df2 = pd.DataFrame(People)

# %%
df2
# Out:
#        Name           Email       Number
# 0  Ashutosh   abc@email.com       887773
# 1     Akash    cv@gmail.com      3343443
# 2      Anuj   Abc@gmail.com     34334343
# 3     Chand    hgj@mail.com     34334343
# 4      Amit    xyz@mail.com   3434343532
# 5  Narendra  loloo@mail.com    867556545
# 6   Salaman    fgv@mail.com  35467887655

# %%
df2['Email']
# Out:
# 0     abc@email.com
# 1      cv@gmail.com
# 2     Abc@gmail.com
# 3      hgj@mail.com
# 4      xyz@mail.com
# 5    loloo@mail.com
# 6      fgv@mail.com
# Name: Email, dtype: object

# %%
type(df2['Email'])
# Out:
# pandas.core.series.Series

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.count
# Out:
# <bound method DataFrame.count of        Name           Email       Number
# 0  Ashutosh   abc@email.com       887773
# 1     Akash    cv@gmail.com      3343443
# 2      Anuj   Abc@gmail.com     34334343
# 3     Chand    hgj@mail.com     34334343
# 4      Amit    xyz@mail.com   3434343532
# 5  Narendra  loloo@mail.com    867556545
# 6   Salaman    fgv@mail.com  35467887655>

# %%
df2[['Name','Email']]
# Out:
#        Name           Email
# 0  Ashutosh   abc@email.com
# 1     Akash    cv@gmail.com
# 2      Anuj   Abc@gmail.com
# 3     Chand    hgj@mail.com
# 4      Amit    xyz@mail.com
# 5  Narendra  loloo@mail.com
# 6   Salaman    fgv@mail.com

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df2.columns
# Out:
# Index(['Name', 'Email', 'Number'], dtype='object')

# %%
#iloc #iloc allows us to get the row by integer 

df2.iloc[0]
# Out:
# Name           Ashutosh
# Email     abc@email.com
# Number           887773
# Name: 0, dtype: object

# %%
df2.iloc[[0,1,2],0] # to get specific  column along with row we will add a second argument
# Out:
# 0    Ashutosh
# 1       Akash
# 2        Anuj
# Name: Name, dtype: object

# %%
df2.iloc[1,1]
# Out:
# 'cv@gmail.com'

# %%
#loc #we get the data by labels which is index automatically added to dataframe start from 0

# %%
df2
# Out:
#        Name           Email       Number
# 0  Ashutosh   abc@email.com       887773
# 1     Akash    cv@gmail.com      3343443
# 2      Anuj   Abc@gmail.com     34334343
# 3     Chand    hgj@mail.com     34334343
# 4      Amit    xyz@mail.com   3434343532
# 5  Narendra  loloo@mail.com    867556545
# 6   Salaman    fgv@mail.com  35467887655

# %%
df2.loc[0:2]
# Out:
#        Name          Email    Number
# 0  Ashutosh  abc@email.com    887773
# 1     Akash   cv@gmail.com   3343443
# 2      Anuj  Abc@gmail.com  34334343

# %%
df2.loc[[0,1,2],['Name','Email']]
# Out:
#        Name          Email
# 0  Ashutosh  abc@email.com
# 1     Akash   cv@gmail.com
# 2      Anuj  Abc@gmail.com

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:500,['Hobbyist','UndergradMajor']]
# Out:
#     Hobbyist                                     UndergradMajor
# 0        Yes  Computer science, computer engineering, or sof...
# 1         No  Computer science, computer engineering, or sof...
# 2        Yes                                                NaN
# 3        Yes  Computer science, computer engineering, or sof...
# 4        Yes  Computer science, computer engineering, or sof...
# ..       ...                                                ...
# 496      Yes  Computer science, computer engineering, or sof...
# 497      Yes  Computer science, computer engineering, or sof...
# 498      Yes  Fine arts or performing arts (such as graphic ...
# 499      Yes  A social science (such as anthropology, psycho...
# 500       No  Computer science, computer engineering, or sof...
#
# [501 rows x 2 columns]

# %%
df.loc[0:500,'Hobbyist':'WelcomeChange']
# Out:
#     Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0        Yes   NaN         13  Monthly        NaN            NaN
# 1         No   NaN         19      NaN        NaN            NaN
# 2        Yes   NaN         15      NaN        NaN            NaN
# 3        Yes  25.0         18      NaN        NaN            NaN
# 4        Yes  31.0         16      NaN        NaN            NaN
# ..       ...   ...        ...      ...        ...            ...
# 496      Yes  32.0         18      NaN        NaN            NaN
# 497      Yes  40.0         19   Yearly   115000.0       115000.0
# 498      Yes  31.0          7   Yearly   140000.0       140000.0
# 499      Yes  41.0          8   Weekly     3120.0       156000.0
# 500       No  41.0          9   Yearly    74000.0        55967.0
#
#                 Country          CurrencyDesc CurrencySymbol  \
# 0               Germany         European Euro            EUR
# ...
