# %%
import pandas as pd

# %%
#to create a data frame in Pandas

#Dataframe_name = {keys:value}

# but we have to put multiple value in one key that's why we use list

People = {'First' : ['Ashutosh','Akash','Anuj','Chand','Amit','Narendra','Salaman'],
          'Last': ['Tiwari','Shukla','Khan','Khan','Tiwari','Shukla','Singh'],
          'Email' : ['abc@email.com','cv@gmail.com','Abc@gmail.com','hgj@mail.com','xyz@mail.com','loloo@mail.com','fgv@mail.com'], 
          'Number':['887773','3343443','34334343','34334343','3434343532','867556545',
'35467887655']}

# %%
df2= pd.DataFrame(People)

# %%
df2.columns
# Out:
# Index(['First', 'Last', 'Email', 'Number'], dtype='object')

# %%
df2.columns =['First_name','Last_name','Emailid','Mobile_Number']

# %%
df2
# Out:
#   First_name Last_name         Emailid Mobile_Number
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2
# Out:
#   First_name Last_name         Emailid Mobile_Number
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = [x.upper() for x in df2.columns]

# %%
df2
# Out:
#   FIRST_NAME LAST_NAME         EMAILID MOBILE_NUMBER
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = df2.columns.str.replace('_',' ')

# %%
df2
# Out:
#   FIRST NAME LAST NAME         EMAILID MOBILE NUMBER
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = df2.columns.str.replace(' ','_')

# %%
df2
# Out:
#   FIRST_NAME LAST_NAME         EMAILID MOBILE_NUMBER
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = [x.lower() for x in df2.columns]

# %%
df2
# Out:
#   first_name last_name         emailid mobile_number
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.rename(columns={'first_name': 'first'},inplace = True)

# %%
df2
# Out:
#       first last_name         emailid mobile_number
# 0  Ashutosh    Tiwari   abc@email.com        887773
# 1     Akash    Shukla    cv@gmail.com       3343443
# 2      Anuj      Khan   Abc@gmail.com      34334343
# 3     Chand      Khan    hgj@mail.com      34334343
# 4      Amit    Tiwari    xyz@mail.com    3434343532
# 5  Narendra    Shukla  loloo@mail.com     867556545
# 6   Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = [x.upper() for x in df2.columns]

# %%
df2
# Out:
#       FIRST LAST_NAME         EMAILID MOBILE_NUMBER
# 0  Ashutosh    Tiwari   abc@email.com        887773
# 1     Akash    Shukla    cv@gmail.com       3343443
# 2      Anuj      Khan   Abc@gmail.com      34334343
# 3     Chand      Khan    hgj@mail.com      34334343
# 4      Amit    Tiwari    xyz@mail.com    3434343532
# 5  Narendra    Shukla  loloo@mail.com     867556545
# 6   Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = df2.columns.str.replace('_',' ')

# %%
df2
# Out:
#       FIRST LAST NAME         EMAILID MOBILE NUMBER
# 0  Ashutosh    Tiwari   abc@email.com        887773
# 1     Akash    Shukla    cv@gmail.com       3343443
# 2      Anuj      Khan   Abc@gmail.com      34334343
# 3     Chand      Khan    hgj@mail.com      34334343
# 4      Amit    Tiwari    xyz@mail.com    3434343532
# 5  Narendra    Shukla  loloo@mail.com     867556545
# 6   Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.columns = [x.upper() for x in df2.columns]

# %%
df2
# Out:
#       FIRST LAST NAME         EMAILID MOBILE NUMBER
# 0  Ashutosh    Tiwari   abc@email.com        887773
# 1     Akash    Shukla    cv@gmail.com       3343443
# 2      Anuj      Khan   Abc@gmail.com      34334343
# 3     Chand      Khan    hgj@mail.com      34334343
# 4      Amit    Tiwari    xyz@mail.com    3434343532
# 5  Narendra    Shukla  loloo@mail.com     867556545
# 6   Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.rename(columns={'FIRST' : 'First_Name','LAST NAME':'Last_Name','EMAILID':'Email_ID','MOBILE NUMBER': 'Mobile_Number'},inplace=True)

# %%
df2
# Out:
#   First_Name Last_Name        Email_ID Mobile_Number
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1      Akash    Shukla    cv@gmail.com       3343443
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.loc[1]
# Out:
# First_Name              Akash
# Last_Name              Shukla
# Email_ID         cv@gmail.com
# Mobile_Number         3343443
# Name: 1, dtype: object

# %%
df2.loc[1] = ['Anuj','Tiwari','anuj@mail.com','99999']

# %%
df2
# Out:
#   First_Name Last_Name        Email_ID Mobile_Number
# 0   Ashutosh    Tiwari   abc@email.com        887773
# 1       Anuj    Tiwari   anuj@mail.com         99999
# 2       Anuj      Khan   Abc@gmail.com      34334343
# 3      Chand      Khan    hgj@mail.com      34334343
# 4       Amit    Tiwari    xyz@mail.com    3434343532
# 5   Narendra    Shukla  loloo@mail.com     867556545
# 6    Salaman     Singh    fgv@mail.com   35467887655

# %%
df2.loc[1,['Last_Name','Email_ID']]
# Out:
# Last_Name           Tiwari
# Email_ID     anuj@mail.com
# Name: 1, dtype: object

# %%
df2.loc[1,['Last_Name','Email_ID']]=['Tripathi','Akassh@mail.com']

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  Akassh@mail.com         99999
# 2       Anuj      Khan    Abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df2.loc[1,'Last_Name']= 'Tiwari'

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj    Tiwari  Akassh@mail.com         99999
# 2       Anuj      Khan    Abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df2.at[1,'Last_Name']= 'Tripathi'

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  Akassh@mail.com         99999
# 2       Anuj      Khan    Abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df2['Email_ID'].str.lower()
# Out:
# 0      abc@email.com
# 1    akassh@mail.com
# 2      abc@gmail.com
# 3       hgj@mail.com
# 4       xyz@mail.com
# 5     loloo@mail.com
# 6       fgv@mail.com
# Name: Email_ID, dtype: object

# %%
df2['Email_ID'] = df2['Email_ID'].str.lower()

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  akassh@mail.com         99999
# 2       Anuj      Khan    abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
apply
map
applymap
replace

# %%
df2['Email_ID'].apply(len)
# Out:
# 0    13
# 1    15
# 2    13
# 3    12
# 4    12
# 5    14
# 6    12
# Name: Email_ID, dtype: int64

# %%
def update_email(Email_ID):
    return Email_ID.upper()

# %%
df2['Email_ID']= df2['Email_ID'].apply(update_email)

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    ABC@EMAIL.COM        887773
# 1       Anuj  Tripathi  AKASSH@MAIL.COM         99999
# 2       Anuj      Khan    ABC@GMAIL.COM      34334343
# 3      Chand      Khan     HGJ@MAIL.COM      34334343
# 4       Amit    Tiwari     XYZ@MAIL.COM    3434343532
# 5   Narendra    Shukla   LOLOO@MAIL.COM     867556545
# 6    Salaman     Singh     FGV@MAIL.COM   35467887655

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    ABC@EMAIL.COM        887773
# 1       Anuj  Tripathi  AKASSH@MAIL.COM         99999
# 2       Anuj      Khan    ABC@GMAIL.COM      34334343
# 3      Chand      Khan     HGJ@MAIL.COM      34334343
# 4       Amit    Tiwari     XYZ@MAIL.COM    3434343532
# 5   Narendra    Shukla   LOLOO@MAIL.COM     867556545
# 6    Salaman     Singh     FGV@MAIL.COM   35467887655

# %%
df2['Email_ID']= df2['Email_ID'].apply(lambda x:x.lower())

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  akassh@mail.com         99999
# 2       Anuj      Khan    abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df2.apply(len)
# Out:
# First_Name       7
# Last_Name        7
# Email_ID         7
# Mobile_Number    7
# dtype: int64

# %%
len(df2['Email_ID'])
# Out:
# 7

# %%
df2.apply(len, axis = 'columns')
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# dtype: int64

# %%
df2.apply(pd.Series.min)
# Out:
# First_Name                Amit
# Last_Name                 Khan
# Email_ID         abc@email.com
# Mobile_Number         34334343
# dtype: object

# %%
df2.apply(lambda x : x.min())
# Out:
# First_Name                Amit
# Last_Name                 Khan
# Email_ID         abc@email.com
# Mobile_Number         34334343
# dtype: object

# %%
df2.applymap(len)
# Out:
#    First_Name  Last_Name  Email_ID  Mobile_Number
# 0           8          6        13              6
# 1           4          8        15              5
# 2           4          4        13              8
# 3           5          4        12              8
# 4           4          6        12             10
# 5           8          6        14              9
# 6           7          5        12             11

# %%
df2.applymap(str.lower)
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   ashutosh    tiwari    abc@email.com        887773
# 1       anuj  tripathi  akassh@mail.com         99999
# 2       anuj      khan    abc@gmail.com      34334343
# 3      chand      khan     hgj@mail.com      34334343
# 4       amit    tiwari     xyz@mail.com    3434343532
# 5   narendra    shukla   loloo@mail.com     867556545
# 6    salaman     singh     fgv@mail.com   35467887655

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  akassh@mail.com         99999
# 2       Anuj      Khan    abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df2['First_Name'].map({'Ashutosh':'Ashu','Anuj':'Akash'})
# Out:
# 0     Ashu
# 1    Akash
# 2    Akash
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# Name: First_Name, dtype: object

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  akassh@mail.com         99999
# 2       Anuj      Khan    abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df2['First_Name'].replace({'Ashutosh':'Ashu','Anuj':'Akash'})
# Out:
# 0        Ashu
# 1       Akash
# 2       Akash
# 3       Chand
# 4        Amit
# 5    Narendra
# 6     Salaman
# Name: First_Name, dtype: object

# %%
df2
# Out:
#   First_Name Last_Name         Email_ID Mobile_Number
# 0   Ashutosh    Tiwari    abc@email.com        887773
# 1       Anuj  Tripathi  akassh@mail.com         99999
# 2       Anuj      Khan    abc@gmail.com      34334343
# 3      Chand      Khan     hgj@mail.com      34334343
# 4       Amit    Tiwari     xyz@mail.com    3434343532
# 5   Narendra    Shukla   loloo@mail.com     867556545
# 6    Salaman     Singh     fgv@mail.com   35467887655

# %%
df = pd.read_csv('Data2020/survey_results_public.csv') #to load data to panadas

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.set_option('Display.max_columns', 85) #to set the number of columns you want to see in a dataframe
pd.set_option('Display.max_rows', 85) #to set the number of columns you want to see in a dataframe

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'})
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df = df.rename(columns={'ConvertedComp':'SalaryUSD'})

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df['SalaryUSD']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 64456   NaN
# 64457   NaN
# 64458   NaN
# 64459   NaN
# 64460   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
 df['SalaryUSD'].head(200)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 195         NaN
# 196    129718.0
# 197         NaN
# 198    105000.0
# 199         NaN
# Name: SalaryUSD, Length: 200, dtype: float64

# %%
df.head(200)
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 0             1                     I am a developer by profession      Yes
# 1             2                     I am a developer by profession       No
# 2             3                        I code primarily as a hobby      Yes
# 3             4                     I am a developer by profession      Yes
# 4             5  I used to be a developer by profession, but no...      Yes
# ..          ...                                                ...      ...
# 195         197             I am a student who is learning to code      Yes
# 196         198                     I am a developer by profession      Yes
# 197         199  I used to be a developer by profession, but no...       No
# 198         200                     I am a developer by profession       No
# 199         201                     I am a developer by profession      Yes
#
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes':True ,'No':False})
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 64456     True
# 64457     True
# 64458     True
# 64459     True
# 64460     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist']=df['Hobbyist'].map({'Yes':True ,'No':False})

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession     True
# 1               2                     I am a developer by profession    False
# 2               3                        I code primarily as a hobby     True
# 3               4                     I am a developer by profession     True
# 4               5  I used to be a developer by profession, but no...     True
# ...           ...                                                ...      ...
# 64456       64858                                                NaN     True
# 64457       64867                                                NaN     True
# 64458       64898                                                NaN     True
# 64459       64925                                                NaN     True
# 64460       65112                                                NaN     True
#
# ...
