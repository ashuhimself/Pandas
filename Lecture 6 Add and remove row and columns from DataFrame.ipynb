# %%
import pandas as pd

# %%
#to create a data frame in Pandas

#Dataframe_name = {keys:value}

# but we have to put multiple value in one key that's why we use list

People = {'First' : ['Ashutosh','Akash','Anuj','Chand','Amit','Narendra','Salaman'],
          'Last': ['Tiwari','Shukla','Khan','Khan','Tiwari','Shukla','Singh'],
          'Email' : ['abc@email.com','cv@gmail.com','Abc@gmail.com','hgj@mail.com','xyz@mail.com','loloo@mail.com','fgv@mail.com'], 
          'Number':['887773','3343443','34334343','34334343','3434343532','867556545',
'35467887655']}

# %%
df2 = pd.DataFrame(People)

# %%
df2['First'] + ' ' + df2['Last']
# Out:
# 0    Ashutosh Tiwari
# 1       Akash Shukla
# 2          Anuj Khan
# 3         Chand Khan
# 4        Amit Tiwari
# 5    Narendra Shukla
# 6      Salaman Singh
# dtype: object

# %%
df2['Full_Name'] = df2['First'] + ' ' + df2['Last']

# %%
df2
# Out:
#       First    Last           Email       Number        Full_Name
# 0  Ashutosh  Tiwari   abc@email.com       887773  Ashutosh Tiwari
# 1     Akash  Shukla    cv@gmail.com      3343443     Akash Shukla
# 2      Anuj    Khan   Abc@gmail.com     34334343        Anuj Khan
# 3     Chand    Khan    hgj@mail.com     34334343       Chand Khan
# 4      Amit  Tiwari    xyz@mail.com   3434343532      Amit Tiwari
# 5  Narendra  Shukla  loloo@mail.com    867556545  Narendra Shukla
# 6   Salaman   Singh    fgv@mail.com  35467887655    Salaman Singh

# %%
df2.drop(columns=['First','Last'])
# Out:
#             Email       Number        Full_Name
# 0   abc@email.com       887773  Ashutosh Tiwari
# 1    cv@gmail.com      3343443     Akash Shukla
# 2   Abc@gmail.com     34334343        Anuj Khan
# 3    hgj@mail.com     34334343       Chand Khan
# 4    xyz@mail.com   3434343532      Amit Tiwari
# 5  loloo@mail.com    867556545  Narendra Shukla
# 6    fgv@mail.com  35467887655    Salaman Singh

# %%
df2 = df2.drop(columns=['First','Last'])

# %%
df2
# Out:
#             Email       Number        Full_Name
# 0   abc@email.com       887773  Ashutosh Tiwari
# 1    cv@gmail.com      3343443     Akash Shukla
# 2   Abc@gmail.com     34334343        Anuj Khan
# 3    hgj@mail.com     34334343       Chand Khan
# 4    xyz@mail.com   3434343532      Amit Tiwari
# 5  loloo@mail.com    867556545  Narendra Shukla
# 6    fgv@mail.com  35467887655    Salaman Singh

# %%
df2['Full_Name'].str.split(' ')
# Out:
# 0    [Ashutosh, Tiwari]
# 1       [Akash, Shukla]
# 2          [Anuj, Khan]
# 3         [Chand, Khan]
# 4        [Amit, Tiwari]
# 5    [Narendra, Shukla]
# 6      [Salaman, Singh]
# Name: Full_Name, dtype: object

# %%
df2['Full_Name'].str.split(' ',expand =True)
# Out:
#           0       1
# 0  Ashutosh  Tiwari
# 1     Akash  Shukla
# 2      Anuj    Khan
# 3     Chand    Khan
# 4      Amit  Tiwari
# 5  Narendra  Shukla
# 6   Salaman   Singh

# %%
df2[['first','last']] =df2['Full_Name'].str.split(' ',expand =True)

# %%
df2
# Out:
#             Email       Number        Full_Name     first    last
# 0   abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari
# 1    cv@gmail.com      3343443     Akash Shukla     Akash  Shukla
# 2   Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan
# 3    hgj@mail.com     34334343       Chand Khan     Chand    Khan
# 4    xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari
# 5  loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla
# 6    fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh

# %%
df2.append({'first':'tony','last':'stark'}, ignore_index=True)
# Out:
#             Email       Number        Full_Name     first    last
# 0   abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari
# 1    cv@gmail.com      3343443     Akash Shukla     Akash  Shukla
# 2   Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan
# 3    hgj@mail.com     34334343       Chand Khan     Chand    Khan
# 4    xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari
# 5  loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla
# 6    fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh
# 7             NaN          NaN              NaN      tony   stark

# %%
People1 = {'First' : ['Jhon','Bhup','Iron','Avenge'],
          'Last': ['Snow','Lol','man','Death'],
          'Email' : ['dsd@email.com','dfdfd@gmail.com','fddf@gmail.com','gb@64.com'], 
          'Number':['43565432','6543','34534','4356']}

# %%
df3= pd.DataFrame(People1)

# %%
df3
# Out:
#     First   Last            Email    Number
# 0    Jhon   Snow    dsd@email.com  43565432
# 1    Bhup    Lol  dfdfd@gmail.com      6543
# 2    Iron    man   fddf@gmail.com     34534
# 3  Avenge  Death        gb@64.com      4356

# %%
df2
# Out:
#             Email       Number        Full_Name     first    last
# 0   abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari
# 1    cv@gmail.com      3343443     Akash Shukla     Akash  Shukla
# 2   Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan
# 3    hgj@mail.com     34334343       Chand Khan     Chand    Khan
# 4    xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari
# 5  loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla
# 6    fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh

# %%
df2.append(df3, ignore_index = True)
# Out:
#               Email       Number        Full_Name     first    last   First  \
# 0     abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari     NaN
# 1      cv@gmail.com      3343443     Akash Shukla     Akash  Shukla     NaN
# 2     Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan     NaN
# 3      hgj@mail.com     34334343       Chand Khan     Chand    Khan     NaN
# 4      xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari     NaN
# 5    loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla     NaN
# 6      fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh     NaN
# 7     dsd@email.com     43565432              NaN       NaN     NaN    Jhon
# 8   dfdfd@gmail.com         6543              NaN       NaN     NaN    Bhup
# 9    fddf@gmail.com        34534              NaN       NaN     NaN    Iron
# 10        gb@64.com         4356              NaN       NaN     NaN  Avenge
#
#      Last
# 0     NaN
# 1     NaN
# 2     NaN
# ...

# %%
df2 = df2.append(df3, ignore_index = True, sort = False)

# %%
df2.drop(index=4)
# Out:
#               Email       Number        Full_Name     first    last   First  \
# 0     abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari     NaN
# 1      cv@gmail.com      3343443     Akash Shukla     Akash  Shukla     NaN
# 2     Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan     NaN
# 3      hgj@mail.com     34334343       Chand Khan     Chand    Khan     NaN
# 5    loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla     NaN
# 6      fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh     NaN
# 7     dsd@email.com     43565432              NaN       NaN     NaN    Jhon
# 8   dfdfd@gmail.com         6543              NaN       NaN     NaN    Bhup
# 9    fddf@gmail.com        34534              NaN       NaN     NaN    Iron
# 10        gb@64.com         4356              NaN       NaN     NaN  Avenge
#
#      Last
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 5     NaN
# 6     NaN
# 7    Snow
# 8     Lol
# 9     man
# 10  Death

# %%
df2.drop(index=10)
# Out:
#              Email       Number        Full_Name     first    last First  Last
# 0    abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari   NaN   NaN
# 1     cv@gmail.com      3343443     Akash Shukla     Akash  Shukla   NaN   NaN
# 2    Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan   NaN   NaN
# 3     hgj@mail.com     34334343       Chand Khan     Chand    Khan   NaN   NaN
# 4     xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari   NaN   NaN
# 5   loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla   NaN   NaN
# 6     fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh   NaN   NaN
# 7    dsd@email.com     43565432              NaN       NaN     NaN  Jhon  Snow
# 8  dfdfd@gmail.com         6543              NaN       NaN     NaN  Bhup   Lol
# 9   fddf@gmail.com        34534              NaN       NaN     NaN  Iron   man

# %%
df2.drop(index=[10,9,8,7])
# Out:
#             Email       Number        Full_Name     first    last First Last
# 0   abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari   NaN  NaN
# 1    cv@gmail.com      3343443     Akash Shukla     Akash  Shukla   NaN  NaN
# 2   Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan   NaN  NaN
# 3    hgj@mail.com     34334343       Chand Khan     Chand    Khan   NaN  NaN
# 4    xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari   NaN  NaN
# 5  loloo@mail.com    867556545  Narendra Shukla  Narendra  Shukla   NaN  NaN
# 6    fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh   NaN  NaN

# %%
df2.drop(index=df2[df2['last']== 'Shukla'].index)
# Out:
#               Email       Number        Full_Name     first    last   First  \
# 0     abc@email.com       887773  Ashutosh Tiwari  Ashutosh  Tiwari     NaN
# 2     Abc@gmail.com     34334343        Anuj Khan      Anuj    Khan     NaN
# 3      hgj@mail.com     34334343       Chand Khan     Chand    Khan     NaN
# 4      xyz@mail.com   3434343532      Amit Tiwari      Amit  Tiwari     NaN
# 6      fgv@mail.com  35467887655    Salaman Singh   Salaman   Singh     NaN
# 7     dsd@email.com     43565432              NaN       NaN     NaN    Jhon
# 8   dfdfd@gmail.com         6543              NaN       NaN     NaN    Bhup
# 9    fddf@gmail.com        34534              NaN       NaN     NaN    Iron
# 10        gb@64.com         4356              NaN       NaN     NaN  Avenge
#
#      Last
# 0     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 6     NaN
# 7    Snow
# 8     Lol
# 9     man
# 10  Death
